# %%
"""1. Tratamento de exceções básicas: Escreva um programa que peça ao usuário
dois números e faça a divisão do primeiro pelo segundo. Se o usuário inserir
um valor inválido ou tentar dividir por zero, o programa deve exibir uma
mensagem de erro apropriada."""

try:
    x = float(input("entre com o valor"))
    y = float(input("entre com o valor"))
    resultado = x/y
    print(resultado)

except ZeroDivisionError:
    print("não foi possivel, tente novamente")
except: 
    print("deu ruim")

finally:
    print("tenha um bom dia")
# Out:
# 0.75
# tenha um bom dia

# %%
"""2. Capturando exceções múltiplas: Crie um programa que peça ao usuário o
nome de uma cor e mostre seu valor em RGB de acordo com um dicionário
pré-definido. O programa deve tratar exceções caso o nome da cor não exista
no dicionário.

cores = {'vermelho': (255, 0, 0), 'verde': (0, 255, 0), 'azul':
(0, 0, 255)}"""

cores = {
    'vermelho':(255, 0, 0),
    "verde": (0, 255, 0),
    "azul": (0, 0, 255)
}

try:
    nome_cor = input("Escolha uma cor(Vermelho, verde ou azul): ").lower().strip()
    rgb = cores[nome_cor]
    print(f"🎨 O código RGB de '{nome_cor}' é: {rgb}")
    

except KeyError:
    print(f" Opa! A cor '{nome_cor}' não está no nosso catálogo.")

finally:
    print("consulta finalizada!")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 11
#       7 (0, 0, 255)}"""
#       8
#       9 cores = {
#      10     'vermelho':(255, 0, 0),
# ---> 11     verde: (0, 255, 0),
#      12     "azul": (0, 0, 255)
#      13 }
#      14
#
# NameError: name 'verde' is not defined
